# %% [markdown]
# # Linear Regression Using Gradient Descent
#
# [Adarsh Menon](https://www.youtube.com/watch?v=4PHI11lX11I)

# %% [markdown]
# ## Import modules

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
plt.rcParams['figure.figsize'] = (12.0, 9.0)

# %% [markdown]
# ## Import datasets

# %%
url = 'https://raw.githubusercontent.com/chasinginfinity/ml-from-scratch/master/02%20Linear%20Regression%20using%20Gradient%20Descent/data.csv'
df = pd.read_csv(url, names=['X', 'y']) # X: independent variable
                                        # y: dependent variable

# %% [markdown]
# ## Quick EDA

# %%
df.head()
# Out:
#            X          y
# 0  32.502345  31.707006
# 1  53.426804  68.777596
# 2  61.530358  62.562382
# 3  47.475640  71.546632
# 4  59.813208  87.230925

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X       100 non-null    float64
#  1   y       100 non-null    float64
# dtypes: float64(2)
# memory usage: 1.7 KB

# %% [markdown]
# ## Preprocessing input data

# %%
X = df.iloc[:, 0]
y = df.iloc[:, 1]
plt.scatter(X, y)
plt.show()

# %% [markdown]
# ## Building the model

# %%
m = 0
c = 0

L = 0.0001
epochs = 2000

n = float(len(X))

for i in range(len(X)):
    y_pred = m*X + c
    D_m = (-2/n) * sum(X * (y - y_pred))
    D_c = (-2/n) * sum(y - y_pred)
    m = m - L * D_m
    c = c - L * D_c

print(m, c)
# Out:
# 1.4788027175308358 0.03507497059234177

# %% [markdown]
# ## Making Predictions

# %%
y_pred = m*X + c

plt.scatter(X, y)
plt.scatter(X, y_pred)
plt.show()

# %% [markdown]
# ## Regression Line

# %%
plt.scatter(X, y)
plt.plot([min(X), max(X)], [min(y_pred), max(y_pred)], color='red')
plt.show()
