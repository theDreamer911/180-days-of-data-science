# %% [markdown]
# ## 1. Importing Dependencies

# %%
## Install the latest package that build for RL
# !pip install stable-baselines3[extras]

# %%
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3 import PPO
import gym
import os

# %% [markdown]
# ## 2. Load Environment
#
# For more info: [link](https://github.com/openai/gym/blob/master/gym/envs/classic_control/cartpole.py)

# %%
environment_name = 'CartPole-v0'
env = gym.make(environment_name)

# %%
environment_name
# Out:
# 'CartPole-v0'

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score += reward
    print('Episode:{} Score:{}'.format(episode, score))
# env.close()
# Out:
# Episode:1 Score:28.0
# Episode:2 Score:9.0
# Episode:3 Score:20.0
# Episode:4 Score:17.0
# Episode:5 Score:45.0

# %%
env.close()

# %% [markdown]
# ### Understanding the Environment

# %%
env.action_space
# Out:
# Discrete(2)

# %%
env.action_space.sample()
# Out:
# 0

# %%
env.observation_space
# Out:
# Box(-3.4028234663852886e+38, 3.4028234663852886e+38, (4,), float32)

# %%
env.observation_space.sample()
# Out:
# array([ 3.5214880e-01, -2.6648153e+38,  1.9150622e-01, -1.9533108e+38],
#       dtype=float32)

# %% [markdown]
# ## 3. Train an RL Model

# %% [markdown]
# **It's better to check your CUDA first in your NVIDIA**
#
# It can be skipped

# %%
# pip3 install torch==1.9.0+cu111 torchvision==0.10.0+cu111 torchaudio===0.9.0 -f https://download.pytorch.org/whl/torch_stable.html

# %%
# Make Your Directory first
log_path = os.path.join('Training', 'Logs')

# %%
log_path
# Out:
# 'Training\\Logs'

# %%
env = gym.make(environment_name)
env = DummyVecEnv([lambda: env])
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cuda device

# %% [markdown]
# another option for policies:
# * MlpPolicy
# * CnnPolicy
# * MultiInputPolicy

# %%
model.learn(total_timesteps=20000)
# Out:
# Logging to Training\Logs\PPO_1
# -----------------------------
# | time/              |      |
# |    fps             | 126  |
# |    iterations      | 1    |
# |    time_elapsed    | 16   |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 192         |
# |    iterations           | 2           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.007992342 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | 0.00289     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.39        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0161     |
# |    value_loss           | 49.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 235         |
# |    iterations           | 3           |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008748036 |
# |    clip_fraction        | 0.0616      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.667      |
# |    explained_variance   | 0.0916      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.7        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0191     |
# |    value_loss           | 44.1        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 265        |
# |    iterations           | 4          |
# |    time_elapsed         | 30         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.00932193 |
# |    clip_fraction        | 0.0899     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.633     |
# |    explained_variance   | 0.204      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 27.1       |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0196    |
# |    value_loss           | 55.6       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 286         |
# |    iterations           | 5           |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008631389 |
# |    clip_fraction        | 0.082       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.603      |
# |    explained_variance   | 0.298       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30          |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0174     |
# |    value_loss           | 67.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 303         |
# |    iterations           | 6           |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.008789324 |
# |    clip_fraction        | 0.0539      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.59       |
# |    explained_variance   | 0.31        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.2        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0123     |
# |    value_loss           | 64.9        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 316          |
# |    iterations           | 7            |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0027388898 |
# |    clip_fraction        | 0.0243       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.592       |
# |    explained_variance   | 0.498        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17.7         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.0073      |
# |    value_loss           | 49.7         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 325         |
# |    iterations           | 8           |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.004364022 |
# |    clip_fraction        | 0.0545      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.576      |
# |    explained_variance   | 0.735       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 31          |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00689    |
# |    value_loss           | 50.7        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 333          |
# |    iterations           | 9            |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0039645554 |
# |    clip_fraction        | 0.0291       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.592       |
# |    explained_variance   | 0.62         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 22.7         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00139     |
# |    value_loss           | 65           |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 340          |
# |    iterations           | 10           |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0027969028 |
# |    clip_fraction        | 0.0164       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.57        |
# |    explained_variance   | 0.647        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 57.7         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00201     |
# |    value_loss           | 62           |
# ------------------------------------------

# %% [markdown]
# ## 4. Save and Reload Model

# %%
PPO_Path = os.path.join('Training', 'Saved_Model', 'PPO_Model_Cartpole')

# %%
model.save(PPO_Path)

# %%
del model

# %%
PPO_Path
# Out:
# 'Training\\Saved_Model\\PPO_Model_Cartpole'

# %%
model = PPO.load(PPO_Path, env=env)

# %%
model.learn(total_timesteps=1000)
# Out:
# Logging to Training\Logs\PPO_2
# -----------------------------
# | time/              |      |
# |    fps             | 689  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------

# %% [markdown]
# ## 5. Evaluation

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# c:\users\asus\appdata\local\programs\python\python39\lib\site-packages\stable_baselines3\common\evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# (200.0, 0.0)

# %%
env.close()

# %% [markdown]
# ## 6. Test

# %%
episodes = 5
for episode in range(1, episodes+1):
    obs = env.reset()
    done = False
    score = 0
    
    while not done:
        env.render()
        action, _ = model.predict(obs)
        obs, reward, done, info = env.step(action)
        score += reward
    print('Episode:{} Score:{}'.format(episode, score))
# env.close()
# Out:
# Episode:1 Score:[200.]
# Episode:2 Score:[200.]
# Episode:3 Score:[200.]
# Episode:4 Score:[200.]
# Episode:5 Score:[200.]

# %%
env.close()

# %%
obs = env.reset()

# %%
obs
# Out:
# array([[ 0.01522005, -0.04554836, -0.01899192,  0.03984968]],
#       dtype=float32)

# %%
action, _ = model.predict(obs)

# %%
env.action_space.sample()
# Out:
# 1

# %%
env.step(action)
# Out:
# (array([[ 0.01430908,  0.14984071, -0.01819493, -0.25876436]],
#        dtype=float32),
#  array([1.], dtype=float32),
#  array([False]),
#  [{}])

# %% [markdown]
# ## 7. Viewing Logs in Tensorboard

# %%
training_log_path = os.path.join(log_path, 'PPO_1')

# %%
training_log_path
# Out:
# 'Training\\Logs\\PPO_1'

# %%
# !tensorboard --logdir={training_log_path}
# Out:
# ^C

# %% [markdown]
# The command tensorboard that run from jupyter will not prompt anything
#
# but actually open the port 6006 just like if using command
#
# To stop it press ctrl+c or interrupt the kernel

# %% [markdown]
# ## 8. Adding a Callback to the Training Stage

# %%
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold

# %%
save_path = os.path.join('Training', 'Saved_Model')

# %%
stop_callback = StopTrainingOnRewardThreshold(reward_threshold=200, verbose=1)
eval_callback = EvalCallback(env,
                             callback_on_new_best=stop_callback,
                             eval_freq=10000,
                             best_model_save_path=save_path,
                             verbose=1)

# %%
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cuda device

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# Logging to Training\Logs\PPO_3
# -----------------------------
# | time/              |      |
# |    fps             | 715  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 537         |
# |    iterations           | 2           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008320259 |
# |    clip_fraction        | 0.0882      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | 0.00205     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.69        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0123     |
# |    value_loss           | 45.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 501         |
# |    iterations           | 3           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010024866 |
# |    clip_fraction        | 0.0625      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.667      |
# |    explained_variance   | 0.0984      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11          |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0181     |
# |    value_loss           | 33.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 485         |
# |    iterations           | 4           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.010351793 |
# |    clip_fraction        | 0.0945      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.634      |
# |    explained_variance   | 0.231       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.9        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0194     |
# |    value_loss           | 53.5        |
# -----------------------------------------
# c:\users\asus\appdata\local\programs\python\python39\lib\site-packages\stable_baselines3\common\evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=10000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 200          |
# |    mean_reward          | 200          |
# | time/                   |              |
# |    total timesteps      | 10000        |
# | train/                  |              |
# |    approx_kl            | 0.0068070525 |
# |    clip_fraction        | 0.0529       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.614       |
# |    explained_variance   | 0.22         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 25.1         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0148      |
# |    value_loss           | 67.3         |
# ------------------------------------------
# New best mean reward!
# Stopping training because the mean reward 200.00  is above the threshold 200

# %% [markdown]
# ## 9. Change the Policies

# %%
net_arch = [dict(pi=[128,128,128,128], vf=[128,128,128,128])]

# %%
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path, policy_kwargs={'net_arch':net_arch})
# Out:
# Using cuda device

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# Logging to Training\Logs\PPO_4
# -----------------------------
# | time/              |      |
# |    fps             | 590  |
# |    iterations      | 1    |
# |    time_elapsed    | 3    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 454         |
# |    iterations           | 2           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.015335293 |
# |    clip_fraction        | 0.228       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.681      |
# |    explained_variance   | 0.00278     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.06        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0255     |
# |    value_loss           | 21.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 420         |
# |    iterations           | 3           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.014968608 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.642      |
# |    explained_variance   | 0.412       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.9        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0317     |
# |    value_loss           | 28.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 403         |
# |    iterations           | 4           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.013641341 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.602      |
# |    explained_variance   | 0.305       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.8        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0251     |
# |    value_loss           | 46.5        |
# -----------------------------------------
# Eval num_timesteps=10000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 200         |
# |    mean_reward          | 200         |
# | time/                   |             |
# |    total timesteps      | 10000       |
# | train/                  |             |
# |    approx_kl            | 0.009815488 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.574      |
# |    explained_variance   | 0.4         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.04        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0207     |
# |    value_loss           | 44.7        |
# -----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 379   |
# |    iterations      | 5     |
# |    time_elapsed    | 26    |
# |    total_timesteps | 10240 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 376         |
# |    iterations           | 6           |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.011061033 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.558      |
# |    explained_variance   | 0.525       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.2        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0107     |
# |    value_loss           | 50.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 375         |
# |    iterations           | 7           |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.006834236 |
# |    clip_fraction        | 0.0643      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.585      |
# |    explained_variance   | 0.622       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21          |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00285    |
# |    value_loss           | 41.2        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 374          |
# |    iterations           | 8            |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0028862406 |
# |    clip_fraction        | 0.0323       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.555       |
# |    explained_variance   | 0.562        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 22.2         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00456     |
# |    value_loss           | 74.9         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 372          |
# |    iterations           | 9            |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0069774953 |
# |    clip_fraction        | 0.0466       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.564       |
# |    explained_variance   | 0.487        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 46           |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00253     |
# |    value_loss           | 83.9         |
# ------------------------------------------
# Eval num_timesteps=20000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 200          |
# |    mean_reward          | 200          |
# | time/                   |              |
# |    total timesteps      | 20000        |
# | train/                  |              |
# |    approx_kl            | 0.0064020227 |
# |    clip_fraction        | 0.0369       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.542       |
# |    explained_variance   | 0.159        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 28.7         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00204     |
# |    value_loss           | 135          |
# ------------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 364   |
# |    iterations      | 10    |
# |    time_elapsed    | 56    |
# |    total_timesteps | 20480 |
# ------------------------------

# %% [markdown]
# ## 10 Using Alternate Algorithm

# %%
from stable_baselines3 import DQN

# %%
model = DQN('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cuda device

# %%
model.learn(total_timesteps=20000)
# Out:
# Logging to Training\Logs\DQN_1
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.946    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 306      |
# |    time_elapsed     | 0        |
# |    total timesteps  | 114      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.898    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 521      |
# |    time_elapsed     | 0        |
# |    total timesteps  | 215      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.863    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 635      |
# |    time_elapsed     | 0        |
# |    total timesteps  | 289      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.816    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 770      |
# |    time_elapsed     | 0        |
# |    total timesteps  | 387      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.774    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 845      |
# |    time_elapsed     | 0        |
# |    total timesteps  | 475      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.735    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 925      |
# |    time_elapsed     | 0        |
# |    total timesteps  | 557      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.705    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 988      |
# |    time_elapsed     | 0        |
# |    total timesteps  | 622      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.658    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 1091     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 719      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.618    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 1172     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 805      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.577    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 1244     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 890      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.512    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 1376     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1027     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.464    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 1461     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1128     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.436    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 1460     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1188     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.392    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 1527     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1281     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.31     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 1668     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1453     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.277    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 1706     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1523     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.237    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 1742     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1606     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.172    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 1830     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1744     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.137    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 1858     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1817     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.0966   |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 1890     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 1902     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 1942     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 2015     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 1958     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 2081     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 1977     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 2157     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 1967     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 2210     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 1991     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 2272     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 2033     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 2384     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 2084     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 2504     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 2065     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 2559     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 2069     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 2620     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 2078     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 2685     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 2088     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 2760     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 2114     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 2855     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 2123     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 2925     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 2134     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 3000     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 2143     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 3073     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 2142     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 3129     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 2166     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 3205     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 2202     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 3327     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 2237     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 3440     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 2242     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 3503     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 2259     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 3570     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 2265     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 3641     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 2268     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 3712     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 2270     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 3779     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 2287     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 3875     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 2306     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 3973     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 2308     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 4035     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 2329     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 4115     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 2335     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 4191     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 2349     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 4283     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 2354     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 4356     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 2352     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 4414     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 2364     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 4483     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 2368     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 4556     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 2399     |
# |    time_elapsed     | 1        |
# |    total timesteps  | 4689     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 1900     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 4824     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 1902     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 4913     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 1919     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 5011     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 1930     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 5090     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 1943     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 5180     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 1947     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 5245     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 1961     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 5339     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 1989     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 5478     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 2006     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 5575     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 2040     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 5736     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 2058     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 5837     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 2083     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 5970     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 2102     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 6077     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 2111     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 6163     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 2118     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 6242     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 2120     |
# |    time_elapsed     | 2        |
# |    total timesteps  | 6305     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 2124     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 6375     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 2134     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 6473     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 2138     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 6540     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 2145     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 6622     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 2155     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 6714     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 2172     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 6832     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 2199     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 6983     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 2222     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 7117     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 2231     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 7198     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 2245     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 7315     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 2253     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 7398     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 2261     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 7493     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 2263     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 7559     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 2262     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 7618     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 2266     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 7696     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 2274     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 7793     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 2282     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 7884     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 2303     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 8025     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 2314     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 8124     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 2316     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 8188     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 2319     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 8273     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 2321     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 8338     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 2331     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 8445     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 2336     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 8528     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 2351     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 8657     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 2357     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 8731     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 2365     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 8833     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 2376     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 8944     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 2379     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 9018     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 2393     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 9139     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 2400     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 9236     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 2406     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 9324     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 2409     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 9397     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 2421     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 9490     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 2427     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 9585     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 2441     |
# |    time_elapsed     | 3        |
# |    total timesteps  | 9713     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 2454     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 9829     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 2453     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 9890     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 2459     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 9983     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 2449     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 10054    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 2453     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 10123    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 2469     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 10241    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 2476     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 10331    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 2492     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 10478    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 2500     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 10573    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 2508     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 10677    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 2518     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 10792    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 2526     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 10898    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 2531     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 10986    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 2537     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 11087    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 2541     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 11175    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 2544     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 11260    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 2550     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 11359    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 2549     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 11421    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 504      |
# |    fps              | 2546     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 11479    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 508      |
# |    fps              | 2555     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 11570    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 512      |
# |    fps              | 2554     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 11629    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 516      |
# |    fps              | 2557     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 11690    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 520      |
# |    fps              | 2565     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 11768    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 524      |
# |    fps              | 2563     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 11834    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 528      |
# |    fps              | 2571     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 11913    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 532      |
# |    fps              | 2570     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 11985    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 536      |
# |    fps              | 2575     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 12077    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 540      |
# |    fps              | 2579     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 12176    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 544      |
# |    fps              | 2589     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 12298    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 548      |
# |    fps              | 2590     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 12365    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 552      |
# |    fps              | 2588     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 12426    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 556      |
# |    fps              | 2591     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 12518    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 560      |
# |    fps              | 2596     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 12639    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 564      |
# |    fps              | 2608     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 12753    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 568      |
# |    fps              | 2611     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 12835    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 572      |
# |    fps              | 2614     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 12921    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 576      |
# |    fps              | 2616     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 13011    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 580      |
# |    fps              | 2614     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 13063    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 584      |
# |    fps              | 2627     |
# |    time_elapsed     | 5        |
# |    total timesteps  | 13184    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 588      |
# |    fps              | 2633     |
# |    time_elapsed     | 5        |
# |    total timesteps  | 13288    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 592      |
# |    fps              | 2638     |
# |    time_elapsed     | 5        |
# |    total timesteps  | 13381    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 596      |
# |    fps              | 2641     |
# |    time_elapsed     | 5        |
# |    total timesteps  | 13472    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 600      |
# |    fps              | 2640     |
# |    time_elapsed     | 5        |
# |    total timesteps  | 13540    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 604      |
# |    fps              | 2641     |
# |    time_elapsed     | 5        |
# |    total timesteps  | 13623    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 608      |
# |    fps              | 2641     |
# |    time_elapsed     | 5        |
# |    total timesteps  | 13696    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# ...
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 684      |
# |    fps              | 2689     |
# |    time_elapsed     | 5        |
# |    total timesteps  | 15321    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 688      |
# |    fps              | 2689     |
# |    time_elapsed     | 5        |
# |    total timesteps  | 15391    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 692      |
# |    fps              | 2687     |
# |    time_elapsed     | 5        |
# |    total timesteps  | 15458    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 696      |
# |    fps              | 2702     |
# |    time_elapsed     | 5        |
# |    total timesteps  | 15605    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 700      |
# |    fps              | 2707     |
# |    time_elapsed     | 5        |
# |    total timesteps  | 15697    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 704      |
# |    fps              | 2704     |
# |    time_elapsed     | 5        |
# |    total timesteps  | 15752    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 708      |
# |    fps              | 2709     |
# |    time_elapsed     | 5        |
# |    total timesteps  | 15831    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 712      |
# |    fps              | 2708     |
# |    time_elapsed     | 5        |
# |    total timesteps  | 15900    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 716      |
# |    fps              | 2708     |
# |    time_elapsed     | 5        |
# |    total timesteps  | 15983    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 720      |
# |    fps              | 2710     |
# |    time_elapsed     | 5        |
# |    total timesteps  | 16068    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 724      |
# |    fps              | 2712     |
# |    time_elapsed     | 5        |
# |    total timesteps  | 16153    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 728      |
# |    fps              | 2715     |
# |    time_elapsed     | 5        |
# |    total timesteps  | 16252    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 732      |
# |    fps              | 2715     |
# |    time_elapsed     | 6        |
# |    total timesteps  | 16324    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 736      |
# |    fps              | 2717     |
# |    time_elapsed     | 6        |
# |    total timesteps  | 16414    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 740      |
# |    fps              | 2709     |
# |    time_elapsed     | 6        |
# |    total timesteps  | 16488    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 744      |
# |    fps              | 2596     |
# |    time_elapsed     | 6        |
# |    total timesteps  | 16544    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 748      |
# |    fps              | 2498     |
# |    time_elapsed     | 6        |
# |    total timesteps  | 16632    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 752      |
# |    fps              | 2312     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 16714    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 756      |
# |    fps              | 2315     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 16794    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 760      |
# |    fps              | 2315     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 16853    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 764      |
# |    fps              | 2322     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 16951    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 768      |
# |    fps              | 2325     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 17032    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 772      |
# |    fps              | 2326     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 17106    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 776      |
# |    fps              | 2332     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 17220    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 780      |
# |    fps              | 2335     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 17308    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 784      |
# |    fps              | 2336     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 17374    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 788      |
# |    fps              | 2341     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 17484    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 792      |
# |    fps              | 2346     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 17586    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 796      |
# |    fps              | 2351     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 17690    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 800      |
# |    fps              | 2355     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 17783    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 804      |
# |    fps              | 2357     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 17866    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 808      |
# |    fps              | 2357     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 17931    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 812      |
# |    fps              | 2363     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 18022    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 816      |
# |    fps              | 2365     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 18098    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 820      |
# |    fps              | 2371     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 18218    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 824      |
# |    fps              | 2376     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 18321    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 828      |
# |    fps              | 2382     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 18411    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 832      |
# |    fps              | 2387     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 18521    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 836      |
# |    fps              | 2390     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 18606    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 840      |
# |    fps              | 2398     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 18746    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 844      |
# |    fps              | 2400     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 18819    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 848      |
# |    fps              | 2405     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 18934    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 852      |
# |    fps              | 2414     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 19082    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 856      |
# |    fps              | 2418     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 19164    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 860      |
# |    fps              | 2419     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 19244    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 864      |
# |    fps              | 2422     |
# |    time_elapsed     | 7        |
# |    total timesteps  | 19339    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 868      |
# |    fps              | 2426     |
# |    time_elapsed     | 8        |
# |    total timesteps  | 19434    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 872      |
# |    fps              | 2433     |
# |    time_elapsed     | 8        |
# |    total timesteps  | 19565    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 876      |
# |    fps              | 2438     |
# |    time_elapsed     | 8        |
# |    total timesteps  | 19670    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 880      |
# |    fps              | 2439     |
# |    time_elapsed     | 8        |
# |    total timesteps  | 19746    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 884      |
# |    fps              | 2445     |
# |    time_elapsed     | 8        |
# |    total timesteps  | 19865    |
# ----------------------------------
