# %% [markdown]
# # Weather Predictions Using Neural Prophet
#
# Tutorial : Nicholas Renotte(https://www.youtube.com/watch?v=mgX0Iz4q0bE&t=64s&ab_channel=NicholasRenotte)
#
# Dataset : WeatherAUS[https://raw.githubusercontent.com/nicknochnack/Forecasting-Weather-with-Neural-Prophet/main/weatherAUS.csv]

# %% [markdown]
# ## Import modules and datasets

# %%
from neuralprophet import NeuralProphet
import matplotlib.pyplot as plt
import pandas as pd
import pickle
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-5866e80f6978> in <module>
# ----> 1 from neuralprophet import NeuralProphet
#       2 import matplotlib.pyplot as plt
#       3 import pandas as pd
#       4 import pickle
#
# ModuleNotFoundError: No module named 'neuralprophet'
